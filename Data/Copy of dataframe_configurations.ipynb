# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/Shareddrives/AI Project ISA632/Data/business_reviews.csv")

# %%
df["categories"]
# Out:
# 0        Bars, Nightlife, Whiskey Bars, Burgers, Restau...
# 1        Asian Fusion, Tapas/Small Plates, American (Ne...
# 2        Seafood, Nightlife, Sports Bars, Bars, Restaur...
# 3                           Restaurants, Chinese, Szechuan
# 4                           Restaurants, Chinese, Szechuan
#                                ...
# 56056    Asian Fusion, Restaurants, American (New), Tha...
# 56057    Restaurants, Vegetarian, Beer, Wine & Spirits,...
# 56058    Asian Fusion, Restaurants, American (New), Tha...
# 56059    Donuts, Sandwiches, Soul Food, Food, Coffee & ...
# 56060    Restaurants, Lounges, Asian Fusion, Nightlife,...
# Name: categories, Length: 56061, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56061 entries, 0 to 56060
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    56061 non-null  int64
#  1   review_id     56061 non-null  object
#  2   user_id       56061 non-null  object
#  3   business_id   56061 non-null  object
#  4   stars_x       56061 non-null  int64
#  5   useful        56061 non-null  int64
#  6   funny         56061 non-null  int64
#  7   cool          56061 non-null  int64
#  8   text          56061 non-null  object
#  9   date          56061 non-null  object
#  10  name          56061 non-null  object
#  11  address       56061 non-null  object
#  12  city          56061 non-null  object
#  13  state         56061 non-null  object
#  14  postal_code   56061 non-null  int64
#  15  latitude      56061 non-null  float64
#  16  longitude     56061 non-null  float64
#  17  stars_y       56061 non-null  float64
# ...

# %%
df_slected=df[["stars_y", "categories", "name"]]

# %%
! pip install PyMySQL
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Credentials to database connection
#hostname="localhost"
#dbname="mydb_name"
#uname="brobsoaw"
#pwd="bLeY2vQFGD5XFR4"


# Create SQLAlchemy engine to connect to MySQL Database
engine = create_engine("mysql+pymysql://admin:bLeY2vQFGD5XFR4@brobsoaw-mysql.cskt1xevcmmb.us-east-1.rds.amazonaws.com/yelp")

# Convert dataframe to sql table                                   
df_slected.to_sql('gen_rec_restaurants', engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-cd326add2b1d> in <cell line: 14>()
#      12
#      13 # Convert dataframe to sql table
# ---> 14 df_slected.to_sql('gen_rec_restaurants', engine, index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2985         from pandas.io import sql
#    2986
# -> 2987         return sql.to_sql(
#    2988             self,
#    2989             name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693         )
#     694
# --> 695     return pandas_sql.to_sql(
#     696         frame,
#     697         name,
#
# ...

# %%
#df_slected.to_csv("/content/drive/Shareddrives/AI Project ISA632/Data/business_reviews_cleaned.csv")

# %%
from sqlalchemy import create_engine

# %%
    db_uri = 'mysql+pymysql://admin:bLeY2vQFGD5XFR4@brobsoaw-mysql.cskt1xevcmmb.us-east-1.rds.amazonaws.com/yelp'
    engine = create_engine(db_uri)
    
    genre="Asian"

    # connect to database engine
    conn = engine.connect()
    
    # Query MySQL database
    query = f"SELECT DISTINCT name FROM yelp.gen_rec_restaurants WHERE categories LIKE '%{genre}%' AND stars_y >= 4 LIMIT 5"
    print(query)

    df = pd.read_sql(query, engine)
    
    # Format results as response
    response = f"Here are your customized recommendations. Choice 1: {df['name'][0]}. \n " + f" Choice 2: {df['name'][1]}. \n " + f" Choice 3: {df['name'][2]}. \n " + f" Choice 4: {df['name'][3]}. \n " + f" Choice 5: {df['name'][4]}. \n "
    
    conn.close()
# Out:
# SELECT DISTINCT name FROM yelp.gen_rec_restaurants WHERE categories LIKE '%Asian%' AND stars_y >= 4 LIMIT 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-d60848592fca> in <cell line: 13>()
#      11 print(query)
#      12
# ---> 13 df = pd.read_sql(query, engine)
#      14
#      15 # Format results as response
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     588         )
#     589     else:
# --> 590         return pandas_sql.read_query(
#     591             sql,
#     592             index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1558         args = _convert_params(sql, params)
#    1559
# ...
